# %% [markdown]
# ### **Importing libraries**

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### **Loading the Dataset**

# %%
employee = pd.read_excel('/content/Employee Sample Data - Copy.xlsx')

# %%
employee.head(10)
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity   Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black  55.0 2016-04-08       141604.0
# 1           Manufacturing    Male      Asian  59.0 1997-11-29        99975.0
# 2     Speciality Products  Female  Caucasian  50.0 2006-10-26       163099.0
# 3           Manufacturing  Female  Caucasian  26.0 2019-09-27        84913.0
# 4           Manufacturing    Male      Asian  55.0 1995-11-20        95409.0
# 5               Corporate    Male      Asian  57.0 2017-01-24        50994.0
# 6               Corporate  Female  Caucasian  27.0 2020-07-01       119746.0
# 7           Manufacturing    Male      Black  25.0 2020-05-16        41336.0
# 8           Manufacturing    Male  Caucasian  29.0 2019-01-25       113527.0
# 9     Speciality Products  Female  Caucasian  34.0 2018-06-13        77203.0
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# 1     0.00          China  Chongqing        NaT
# 2     0.20  United States    Chicago        NaT
# 3     0.07  United States    Chicago        NaT
# 4     0.00  United States    Phoenix        NaT
# 5     0.00          China  Chongqing        NaT
# 6     0.10  United States    Phoenix        NaT
# 7     0.00  United States      Miami 2021-05-20
# 8     0.06  United States     Austin        NaT
# 9     0.00  United States    Chicago        NaT

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      998 non-null    object
#  2   Job Title      999 non-null    object
#  3   Department     998 non-null    object
#  4   Business Unit  1000 non-null   object
#  5   Gender         999 non-null    object
#  6   Ethnicity      993 non-null    object
#  7   Age            994 non-null    float64
#  8   Hire Date      993 non-null    datetime64[ns]
#  9   Annual Salary  989 non-null    float64
#  10  Bonus %        992 non-null    float64
#  11  Country        998 non-null    object
#  12  City           998 non-null    object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), object(9)
# memory usage: 109.5+ KB

# %%
employee.isnull().sum()
# Out:
# EEID               0
# Full Name          2
# Job Title          1
# Department         2
# Business Unit      0
# Gender             1
# Ethnicity          7
# Age                6
# Hire Date          7
# Annual Salary     11
# Bonus %            8
# Country            2
# City               2
# Exit Date        915
# dtype: int64

# %%
employee['City'].fillna(employee['City'].mode()[0], inplace=True)
employee['Country'].fillna(employee['Country'].mode()[0], inplace=True)
employee['Gender'].fillna(employee['Gender'].mode()[0], inplace=True)
employee['Department'].fillna(employee['Department'].mode()[0], inplace=True)
employee['Job Title'].fillna(employee['Job Title'].mode()[0], inplace=True)
employee['Ethnicity'].fillna(employee['Ethnicity'].mode()[0], inplace=True)

# %%
employee['Full Name'].fillna('unknown', inplace=True)

# %%
employee['Age'].fillna(employee['Age'].median(), inplace=True)

# %%
employee['Bonus %'].fillna(employee['Bonus %'].median(), inplace = True) # changes were made
employee['Annual Salary'].fillna(employee['Annual Salary'].median(), inplace = True) # changes were made

# %%
employee.isnull().sum()
# Out:
# EEID               0
# Full Name          0
# Job Title          0
# Department         0
# Business Unit      0
# Gender             0
# Ethnicity          0
# Age                0
# Hire Date          7
# Annual Salary      0
# Bonus %            0
# Country            0
# City               0
# Exit Date        915
# dtype: int64

# %%
employee.tail(5)
# Out:
#        EEID     Full Name       Job Title  Department        Business Unit  \
# 995  E03094  Wesley Young     Sr. Analyst   Marketing  Speciality Products
# 996  E01909  Lillian Khan         Analyst     Finance  Speciality Products
# 997  E04398   Oliver Yang        Director   Marketing  Speciality Products
# 998  E02521   Lily Nguyen     Sr. Analyst     Finance  Speciality Products
# 999  E03545   Sofia Cheng  Vice President  Accounting            Corporate
#
#      Gender  Ethnicity   Age  Hire Date  Annual Salary  Bonus %  \
# 995    Male  Caucasian  33.0 2016-09-18        98427.0     0.00
# 996  Female      Asian  44.0 2010-05-31        47387.0     0.00
# 997    Male      Asian  31.0 2019-06-10       176710.0     0.15
# 998  Female      Asian  33.0 2012-01-28        95960.0     0.00
# 999  Female      Asian  63.0 2020-07-26       216195.0     0.31
#
#            Country      City  Exit Date
# 995  United States  Columbus        NaT
# 996          China   Chengdu 2018-01-08
# 997  United States     Miami        NaT
# 998          China   Chengdu        NaT
# 999  United States     Miami        NaT

# %%
employee.loc[0] = ['E23748','Yousef AbuALi', "AI","IT","bussiness","Male","Asian",20.0,'2018-05-22 00:00:00',19000.0,4.90,"United States","Miami","2020-01-08 00:00:00"]
employee.loc[1] = ['E74548','Jude tuqan', "marketing","bussiness","bussiness","Female","Asian",25.0,'2011-01-03 00:00:00',9000.0,2.90,"United States","Columbus","2018-05-25 00:00:00"]
employee.loc[2] = ['E84048','Jehad tuqan', "bussiness","security","bussiness","Male","Asian",23.0,'2009-09-09 00:00:00',10000.0,0.90,"United States","Columbus","2012-09-18 00:00:00"]
employee.loc[3] = ['E12637','Hamza elabed', "Doctor","doctor","doctor","Male","Asian",19.0,'2020-12-23 00:00:00',15000.0,6.90,"United States","Chicago","2023-08-08 00:00:00"]
employee.loc[4] = ['E40971','issa elabed', "Doctor","doctor","doctor","Male","Asian",22.0,'2021-10-15 00:00:00',15000.0,6.90,"United States","Chicago","2022-03-23 00:00:00"]

# %%
employee.head(5)
# Out:
#      EEID      Full Name  Job Title Department Business Unit  Gender  \
# 0  E23748  Yousef AbuALi         AI         IT     bussiness    Male
# 1  E74548     Jude tuqan  marketing  bussiness     bussiness  Female
# 2  E84048    Jehad tuqan  bussiness   security     bussiness    Male
# 3  E12637   Hamza elabed     Doctor     doctor        doctor    Male
# 4  E40971    issa elabed     Doctor     doctor        doctor    Male
#
#   Ethnicity   Age  Hire Date  Annual Salary  Bonus %        Country      City  \
# 0     Asian  20.0 2018-05-22        19000.0      4.9  United States     Miami
# 1     Asian  25.0 2011-01-03         9000.0      2.9  United States  Columbus
# 2     Asian  23.0 2009-09-09        10000.0      0.9  United States  Columbus
# 3     Asian  19.0 2020-12-23        15000.0      6.9  United States   Chicago
# 4     Asian  22.0 2021-10-15        15000.0      6.9  United States   Chicago
#
#    Exit Date
# 0 2020-01-08
# 1 2018-05-25
# 2 2012-09-18
# 3 2023-08-08
# 4 2022-03-23

# %%
largestSalary = employee.nlargest(1, "Annual Salary")
largestSalary
# Out:
#        EEID     Full Name       Job Title Department  Business Unit  Gender  \
# 989  E04354  Raelynn Rios  Vice President      Sales  Manufacturing  Female
#
#     Ethnicity   Age  Hire Date  Annual Salary  Bonus %        Country  \
# 989    Latino  43.0 2016-08-21       258498.0     0.35  United States
#
#          City Exit Date
# 989  Columbus       NaT

# %%
employee['Exit Date'] = employee['Exit Date'].fillna(pd.to_datetime('2020-12-31'))
employee['Hire Date'] = employee['Hire Date'].fillna(pd.to_datetime('2020-12-31'))
employee['Hire Date'] = pd.to_datetime(employee['Hire Date'])
employee['Exit Date'] = pd.to_datetime(employee['Exit Date'])

# %%
employee.head()
# Out:
#      EEID      Full Name  Job Title Department Business Unit  Gender  \
# 0  E23748  Yousef AbuALi         AI         IT     bussiness    Male
# 1  E74548     Jude tuqan  marketing  bussiness     bussiness  Female
# 2  E84048    Jehad tuqan  bussiness   security     bussiness    Male
# 3  E12637   Hamza elabed     Doctor     doctor        doctor    Male
# 4  E40971    issa elabed     Doctor     doctor        doctor    Male
#
#   Ethnicity   Age  Hire Date  Annual Salary  Bonus %        Country      City  \
# 0     Asian  20.0 2018-05-22        19000.0      4.9  United States     Miami
# 1     Asian  25.0 2011-01-03         9000.0      2.9  United States  Columbus
# 2     Asian  23.0 2009-09-09        10000.0      0.9  United States  Columbus
# 3     Asian  19.0 2020-12-23        15000.0      6.9  United States   Chicago
# 4     Asian  22.0 2021-10-15        15000.0      6.9  United States   Chicago
#
#    Exit Date
# 0 2020-01-08
# 1 2018-05-25
# 2 2012-09-18
# 3 2023-08-08
# 4 2022-03-23

# %%
employee.to_excel("employee.xlsx", index=False)

# %% [markdown]
# # **Data exploration**

# %%
employee['Job Title'].value_counts().plot(kind='bar')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.title('Distribution of Job Titles')
plt.show()

# %% [markdown]
# From this bar plot it seems that the Director, Sr. Manager, vice president, and Manager are the most common jobs.
# on the other side, Doctor, marketing, bussiness, and AI are the least common jobs.

# %%
employee['Department'].value_counts().plot(kind='bar')
plt.xlabel('Department Name')
plt.ylabel('Count')
plt.title('Distribution Department')
plt.show()

# %% [markdown]
# It seems from this bar plot, that the most common department is the IT department followed by the engineering and sales. while doctor, bussiness and security were the least common department.

# %%
employee['Business Unit'].value_counts().plot(kind='bar')
plt.xlabel('Business Unit')
plt.ylabel('Count')
plt.title('Distribution of Business Units')
plt.show()

# %% [markdown]
# it looks from this bar plot the manufacturing, speciality products, corporate, and research & Development units are very common, while bussiness and doctor units are less common, and this because they were less in all columns.

# %%
employee['Gender'].value_counts().plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Distribution Gender')
plt.show()

# %% [markdown]
# This bar plot shows that there is gender balance in the dataset, which means thier is no gender bias.

# %%
employee['Ethnicity'].value_counts().plot(kind='bar')
plt.xlabel('Ethnicity')
plt.ylabel('Count')
plt.title('Distribution for Ethnicity')
plt.show()

# %%
sns.displot(employee, x="Age", col="Gender")
plt.show()

# %%
sns.displot(employee, x="Age")
plt.show()

# %%
sns.displot(employee, x="Annual Salary")
plt.show()

# %% [markdown]
# from this plot it looks that the salary is centered between 50000 and 100000

# %%
sns.boxplot(x='Bonus %', data=employee)
plt.xlabel('Bonus %')
plt.title('Distribution of Bonus %')
plt.show()

# %%
employee.head(3)
# Out:
#     EEID      Full Name  Job Title Department Business Unit  Gender Ethnicity  \
# 0  23748  Yousef AbuALi         AI         IT     bussiness    Male     Asian
# 1  74548     Jude tuqan  marketing  bussiness     bussiness  Female     Asian
# 2  84048    Jehad tuqan  bussiness   security     bussiness    Male     Asian
#
#     Age            Hire Date  Annual Salary  Bonus %        Country      City  \
# 0  20.0  2018-05-22 00:00:00        19000.0      4.9  United States     Miami
# 1  25.0  2011-01-03 00:00:00         9000.0      2.9  United States  Columbus
# 2  23.0  2009-09-09 00:00:00        10000.0      0.9  United States  Columbus
#
#              Exit Date
# 0  2020-01-08 00:00:00
# 1  2018-05-25 00:00:00
# 2  2012-09-18 00:00:00

# %% [markdown]
# this box plot shows that most bonuses are centered between 0-0.5 with some outliers

# %%
employee['Hire Date'] = pd.to_datetime(employee['Hire Date'], errors='coerce')
employee.set_index('Hire Date', inplace=True)


monthly_hires = employee.resample('M').size()


plt.figure(figsize=(12, 6))
monthly_hires.plot(kind='line', marker='o')
plt.xlabel('Hire Date')
plt.ylabel('Number of Hires')
plt.title('Monthly Hiring Trend')
plt.grid(True)
plt.show()

# %%
employee.head(3)
# Out:
#              EEID      Full Name  Job Title Department Business Unit  Gender  \
# Hire Date
# 2018-05-22  23748  Yousef AbuALi         AI         IT     bussiness    Male
# 2011-01-03  74548     Jude tuqan  marketing  bussiness     bussiness  Female
# 2009-09-09  84048    Jehad tuqan  bussiness   security     bussiness    Male
#
#            Ethnicity   Age  Annual Salary  Bonus %        Country      City  \
# Hire Date
# 2018-05-22     Asian  20.0        19000.0      4.9  United States     Miami
# 2011-01-03     Asian  25.0         9000.0      2.9  United States  Columbus
# 2009-09-09     Asian  23.0        10000.0      0.9  United States  Columbus
#
#                       Exit Date
# Hire Date
# 2018-05-22  2020-01-08 00:00:00
# 2011-01-03  2018-05-25 00:00:00
# 2009-09-09  2012-09-18 00:00:00

# %% [markdown]
# this plot shows that by the years the number of people being hired in the company increases. it started with two maximum before 1994, and it increased to reach over 12 after 2019.

# %%
employee['Exit Date'] = pd.to_datetime(employee['Exit Date'], errors='coerce')
employee.set_index('Exit Date', inplace=True)


monthly_exit = employee.resample('M').size()


plt.figure(figsize=(12, 6))
monthly_exit.plot(kind='line', marker='o')
plt.xlabel('Exit Date')
plt.ylabel('Number of Exit')
plt.title('Monthly Exit Trend')
plt.grid(True)
plt.show()

# %% [markdown]
# close to the idea of hiring, the people who left the company varied with time. but during the years 2020-2022 more people left the company than ever.

# %%
employee['Country'].value_counts().plot(kind='bar')
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Distribution of Country')
plt.show()

# %%
employee.head(3)
# Out:
#              EEID      Full Name  Job Title Department Business Unit  Gender  \
# Exit Date
# 2020-01-08  23748  Yousef AbuALi         AI         IT     bussiness    Male
# 2018-05-25  74548     Jude tuqan  marketing  bussiness     bussiness  Female
# 2012-09-18  84048    Jehad tuqan  bussiness   security     bussiness    Male
#
#            Ethnicity   Age  Annual Salary  Bonus %        Country      City
# Exit Date
# 2020-01-08     Asian  20.0        19000.0      4.9  United States     Miami
# 2018-05-25     Asian  25.0         9000.0      2.9  United States  Columbus
# 2012-09-18     Asian  23.0        10000.0      0.9  United States  Columbus

# %%
le = LabelEncoder()

employee['Job Title'] = le.fit_transform(employee['Job Title'])
employee['Department'] = le.fit_transform(employee['Department'])
employee['Business Unit'] = le.fit_transform(employee['Business Unit'])
employee['Gender'] = le.fit_transform(employee['Gender'])
employee['Ethnicity'] = le.fit_transform(employee['Ethnicity'])
employee['Country'] = le.fit_transform(employee['Country'])
employee['City'] = le.fit_transform(employee['City'])

employee.head()
# Out:
#      EEID      Full Name  Job Title  Department  Business Unit  Gender  \
# 0  E23748  Yousef AbuALi          0           4              4       1
# 1  E74548     Jude tuqan         36           7              4       0
# 2  E84048    Jehad tuqan         35           9              4       1
# 3  E12637   Hamza elabed         11           8              5       1
# 4  E40971    issa elabed         11           8              5       1
#
#    Ethnicity   Age  Hire Date  Annual Salary  Bonus %  Country  City  \
# 0          0  20.0 2018-05-22        19000.0      4.9        2     7
# 1          0  25.0 2011-01-03         9000.0      2.9        2     5
# 2          0  23.0 2009-09-09        10000.0      0.9        2     5
# 3          0  19.0 2020-12-23        15000.0      6.9        2     3
# 4          0  22.0 2021-10-15        15000.0      6.9        2     3
#
#    Exit Date
# 0 2020-01-08
# 1 2018-05-25
# 2 2012-09-18
# 3 2023-08-08
# 4 2022-03-23

# %%
numeric_employee = employee.select_dtypes(include=['number'])
matrix = numeric_employee.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# It looks like thier are multiple features that has good correlation. for example annual salary and job title has a high correlation of 0.44 compared to the other, which means the job title affects the salary of a person which makes sense. next is the city and ethnicity with a correlation of 0.21, and this because people with similar ethnicity would live in a similar city.

# %%
sns.pairplot(numeric_employee)
plt.show()

# %% [markdown]
# this was another way I tried, which helps in looking at the relationship between different features using multiple scatter plots in one drawing

# %% [markdown]
# ### **References**

# %% [markdown]
# https://vitalflux.com/pandas-impute-missing-values-mean-median-mode/

# %% [markdown]
# https://www.geeksforgeeks.org/data-visualization-with-python/

# %% [markdown]
# https://realpython.com/pandas-plot-python/

# %% [markdown]
# https://datagy.io/python-correlation-matrix/

# %% [markdown]
# https://stackoverflow.com/questions/29432629/plot-correlation-matrix-using-pandas

# %% [markdown]
# https://toyoutyred.weebly.com/blog/draw-scatter-plot-matplotlib

# %% [markdown]
# https://www.geeksforgeeks.org/python-seaborn-pairplot-method/
