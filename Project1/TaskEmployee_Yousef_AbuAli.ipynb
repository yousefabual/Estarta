# %%
import pandas as pd

# %%
employee = pd.read_excel('/content/Employee Sample Data - Copy.xlsx')

# %%
employee.head(10)
# Out:
#      EEID        Full Name                 Job Title  Department  \
# 0  E02387      Emily Davis                Sr. Manger          IT
# 1  E04105    Theodore Dinh       Technical Architect          IT
# 2  E02572     Luna Sanders                  Director     Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager          IT
# 4  E01639        Austin Vo               Sr. Analyst     Finance
# 5  E00644     Joshua Gupta    Account Representative       Sales
# 6  E01550      Ruby Barnes                   Manager          IT
# 7  E04332      Luke Martin                   Analyst     Finance
# 8  E04533    Easton Bailey                   Manager  Accounting
# 9  E03838  Madeline Walker               Sr. Analyst     Finance
#
#             Business Unit  Gender  Ethnicity   Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black  55.0 2016-04-08       141604.0
# 1           Manufacturing    Male      Asian  59.0 1997-11-29        99975.0
# ...

# %% [markdown]
# # **Data exploration**

# %%
employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      998 non-null    object
#  2   Job Title      999 non-null    object
#  3   Department     998 non-null    object
#  4   Business Unit  1000 non-null   object
#  5   Gender         999 non-null    object
#  6   Ethnicity      993 non-null    object
#  7   Age            994 non-null    float64
#  8   Hire Date      993 non-null    datetime64[ns]
#  9   Annual Salary  989 non-null    float64
#  10  Bonus %        992 non-null    float64
#  11  Country        998 non-null    object
#  12  City           998 non-null    object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(3), object(9)
# memory usage: 109.5+ KB

# %%
employee.isnull().sum()
# Out:
# EEID               0
# Full Name          2
# Job Title          1
# Department         2
# Business Unit      0
# Gender             1
# Ethnicity          7
# Age                6
# Hire Date          7
# Annual Salary     11
# Bonus %            8
# Country            2
# City               2
# Exit Date        915
# dtype: int64

# %%
employee = employee.drop(['Exit Date'], axis=1) # drop because it contains 915 null values

# %%
employee['City'].fillna(employee['City'].mode()[0], inplace=True)
employee['Country'].fillna(employee['Country'].mode()[0], inplace=True)
employee['Gender'].fillna(employee['Gender'].mode()[0], inplace=True)
employee['Department'].fillna(employee['Department'].mode()[0], inplace=True)
employee['Job Title'].fillna(employee['Job Title'].mode()[0], inplace=True)
employee['Ethnicity'].fillna(employee['Ethnicity'].mode()[0], inplace=True)

# %%
employee['Full Name'].fillna('unknown', inplace=True)
employee['Hire Date'].fillna('unkown', inplace=True)

# %%
employee['Age'].fillna(employee['Age'].median(), inplace=True)

# %%
employee['Bonus %'].fillna(employee['Bonus %'].mean(), inplace = True)
employee['Annual Salary'].fillna(employee['Annual Salary'].mean(), inplace = True)

# %%
employee.isnull().sum()
# Out:
# EEID             0
# Full Name        0
# Job Title        0
# Department       0
# Business Unit    0
# Gender           0
# Ethnicity        0
# Age              0
# Hire Date        0
# Annual Salary    0
# Bonus %          0
# Country          0
# City             0
# dtype: int64

# %%
employee.loc[0] = [23748,'Yousef AbuALi', "AI","IT","bussiness","male","arabic",20,'7/17/2013',19000,4.90,"jordan","amman"]
employee.loc[1] = [74548,'Jude tuqan', "marketing","bussiness","bussiness","female","arabic",25,'1/18/2012',9000,2.90,"jordan","amman"]
employee.loc[2] = [84048,'Jehad tuqan', "bussiness","security","bussiness","male","arabic",23,'7/17/2013',10000,0.90,"jordan","amman"]
employee.loc[3] = [12637,'Hamza elabed', "Doctor","doctor","doctor","male","arabic",19,'still training',15000,6.90,"USA","USA"]
employee.loc[4] = [40971,'issa elabed', "Doctor","doctor","doctor","male","arabic",19,'still training',15000,6.90,"USA","USA"]

# %%
employee.head(5)
# Out:
#     EEID      Full Name  Job Title Department Business Unit  Gender Ethnicity  \
# 0  23748  Yousef AbuALi         AI         IT     bussiness    male    arabic
# 1  74548     Jude tuqan  marketing  bussiness     bussiness  female    arabic
# 2  84048    Jehad tuqan  bussiness   security     bussiness    male    arabic
# 3  12637   Hamza elabed     Doctor     doctor        doctor    male    arabic
# 4  40971    issa elabed     Doctor     doctor        doctor    male    arabic
#
#     Age       Hire Date  Annual Salary  Bonus % Country   City
# 0  20.0       7/17/2013        19000.0      4.9  jordan  amman
# 1  25.0       1/18/2012         9000.0      2.9  jordan  amman
# 2  23.0       7/17/2013        10000.0      0.9  jordan  amman
# 3  19.0  still training        15000.0      6.9     USA    USA
# 4  19.0  still training        15000.0      6.9     USA    USA

# %%
largestSalary = employee.nlargest(1, "Annual Salary")
largestSalary
# Out:
#        EEID     Full Name       Job Title Department  Business Unit  Gender  \
# 989  E04354  Raelynn Rios  Vice President      Sales  Manufacturing  Female
#
#     Ethnicity   Age            Hire Date  Annual Salary  Bonus %  \
# 989    Latino  43.0  2016-08-21 00:00:00       258498.0     0.35
#
#            Country      City
# 989  United States  Columbus
